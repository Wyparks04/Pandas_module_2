# %%
# libraries
import pandas as pd

# %%
# review info from class
def disorder_organizer(RawData, disorder_name):
    organized_df = raw_df['Entity', 'Year', disorder_name]
    return organized_df

# %%
# useful methods

# %%
# create a dataframe
df_mental_illness = pd.read_csv('RawData/mental-illnesses-prevalence.csv')
df_mental_illness
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6415     Zimbabwe  ZWE  2015
# 6416     Zimbabwe  ZWE  2016
# 6417     Zimbabwe  ZWE  2017
# 6418     Zimbabwe  ZWE  2018
# 6419     Zimbabwe  ZWE  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              0.223206
# 1                                              0.222454
# 2                                              0.221751
# 3                                              0.220987
# 4                                              0.220183
# ...                                                 ...
# 6415                                           0.201042
# 6416                                           0.201319
# 6417                                           0.201639
# 6418                                           0.201976
# 6419                                           0.202482
#
#       Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              4.996118
# 1                                              4.989290
# 2                                              4.981346
# 3                                              4.976958
# 4                                              4.977782
# ...                                                 ...
# 6415                                           3.407624
# 6416                                           3.410755
# 6417                                           3.411965
# 6418                                           3.406929
# 6419                                           3.395476
#
#       Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              4.713314
# 1                                              4.702100
# 2                                              4.683743
# 3                                              4.673549
# 4                                              4.670810
# ...                                                 ...
# 6415                                           3.184012
# 6416                                           3.187148
# 6417                                           3.188418
# 6418                                           3.172111
# 6419                                           3.137017
#
#       Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              0.703023
# 1                                              0.702069
# 2                                              0.700792
# 3                                              0.700087
# 4                                              0.699898
# ...                                                 ...
# 6415                                           0.538596
# 6416                                           0.538593
# 6417                                           0.538589
# 6418                                           0.538585
# 6419                                           0.538580
#
#       Eating disorders (share of population) - Sex: Both - Age: Age-standardized
# 0                                              0.127700
# 1                                              0.123256
# 2                                              0.118844
# 3                                              0.115089
# 4                                              0.111815
# ...                                                 ...
# 6415                                           0.095652
# 6416                                           0.096662
# 6417                                           0.097330
# 6418                                           0.097909
# 6419                                           0.098295
#
# [6420 rows x 8 columns]

# %%
df_mental_illness.head(10)
df_mental_illness.tail(10)
# Out:
#         Entity Code  Year  \
# 6410  Zimbabwe  ZWE  2010
# 6411  Zimbabwe  ZWE  2011
# 6412  Zimbabwe  ZWE  2012
# 6413  Zimbabwe  ZWE  2013
# 6414  Zimbabwe  ZWE  2014
# 6415  Zimbabwe  ZWE  2015
# 6416  Zimbabwe  ZWE  2016
# 6417  Zimbabwe  ZWE  2017
# 6418  Zimbabwe  ZWE  2018
# 6419  Zimbabwe  ZWE  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 6410                                           0.200465
# 6411                                           0.200450
# 6412                                           0.200552
# 6413                                           0.200720
# 6414                                           0.200902
# 6415                                           0.201042
# 6416                                           0.201319
# 6417                                           0.201639
# 6418                                           0.201976
# 6419                                           0.202482
#
#       Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 6410                                           3.335359
# 6411                                           3.342535
# 6412                                           3.360127
# 6413                                           3.381162
# 6414                                           3.399114
# 6415                                           3.407624
# 6416                                           3.410755
# 6417                                           3.411965
# 6418                                           3.406929
# 6419                                           3.395476
#
#       Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 6410                                           3.184889
# 6411                                           3.183598
# 6412                                           3.183051
# 6413                                           3.183019
# 6414                                           3.183361
# 6415                                           3.184012
# 6416                                           3.187148
# 6417                                           3.188418
# 6418                                           3.172111
# 6419                                           3.137017
#
#       Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 6410                                           0.538595
# 6411                                           0.538598
# 6412                                           0.538599
# 6413                                           0.538599
# 6414                                           0.538597
# 6415                                           0.538596
# 6416                                           0.538593
# 6417                                           0.538589
# 6418                                           0.538585
# 6419                                           0.538580
#
#       Eating disorders (share of population) - Sex: Both - Age: Age-standardized
# 6410                                           0.091427
# 6411                                           0.091719
# 6412                                           0.092329
# 6413                                           0.093430
# 6414                                           0.094608
# 6415                                           0.095652
# 6416                                           0.096662
# 6417                                           0.097330
# 6418                                           0.097909
# 6419                                           0.098295

# %%
column_names = df_mental_illness.columns
print(column_names)df_mental_illness.rename(columns=new_column_names, inplace=True)
column_names = df_mental_illness.columns
print(column_names)

for column in column_names:
    print(column)
    print(column)
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized',
#        'Depressive disorders (share of population) - Sex: Both - Age: Age-standardized',
#        'Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized',
#        'Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized',
#        'Eating disorders (share of population) - Sex: Both - Age: Age-standardized'],
#       dtype='object')
# Entity
# Code
# Year
# Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized
# Depressive disorders (share of population) - Sex: Both - Age: Age-standardized
# Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized
# Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized
# Eating disorders (share of population) - Sex: Both - Age: Age-standardized

# %%
new_column_names = {"Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized" : "Schizophrenia",'Depressive disorders (share of population) - Sex: Both - Age: Age-standardized':'Depression','Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized':'Anxiety','Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized':'Bipolar','Eating disorders (share of population) - Sex: Both - Age: Age-standardized':'Eating Disorder'}

# %%
column_names = df_mental_illness.columns
print(column_names)
for column in column_names:
    print(column)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 column_names = df_mental_illness.columns
#       2 print(column_names)
#       3 for column in column_names:
#
# NameError: name 'df_mental_illness' is not defined

# %%
import pandas as pd

# Data for the dataframe
data = {
    'Hair Type': [
        'All Hair Types', 'Curly', 'Dry', 'Dry', 'Curly', 'All Hair Types', 
        'Damaged', 'Dry', 'Dry'
    ],
    'Product Name': [
        'Kuza Indian Hemp with Chebe Hairdress & Scalp Treatment, 7.7 oz',
        'Kuza Indian Hemp Hair & Scalp Treatment, 8 Oz',
        'Softee Indian Hemp Hair & Scalp Treatment 3 oz. Jar',
        'Mega Growth Profectiv Moisturizing Repairing Leave-in Hair Treatment, 15 oz',
        'Feel It Formula- Strengthening Balm 4oz., All Hair Type, Moisturizing',
        'Jamaican Mango & Lime Nourishing Island Oil Hair Treatment, 8 fl oz., All Hair Type',
        'Softee Hair & Scalp Treatment, Indian Hemp, 5 Ounce',
        'Softee Light And Natural Indian Hemp Hair And Scalp Treatment, 5 Oz',
        'FANTASIA Avocado & Cilantro Leave-in Treatment 178ml/6oz'
    ],
    'Count': [1, 1, 1, 1, 1, 1, 1, 1, 1],
    'Hair Care Key Benefits': [
        'Moisturizing', 'Repairing', 'Conditioning', 'Moisturizing', 
        'Nourishing', 'Nourishing', 'Scalp Care', '', 'Nourishing'
    ],
    'Condition': [
        'New', 'New', 'New', 'New', 'New', 'New', 'New', 'New', 'New'
    ],
    'Ingredient Preference': [
        'Paraben-Free', '', '', '', 'Paraben-Free', 'Paraben-Free', '', '', 'Paraben-Free'
    ],
    'Weight': [
        '', '9.84 lb', '0.24 lbs', '1.1325 POUNDS', '5.47 oz', '0.5 lbs', 
        '1 lb', '1 lb', '0.88 lb'
    ]
}

# Creating the dataframe
data_df = pd.DataFrame(data)

# Display the dataframe
print(data_df)
# Out:
#         Hair Type                                       Product Name  Count  \
# 0  All Hair Types  Kuza Indian Hemp with Chebe Hairdress & Scalp ...      1
# 1           Curly      Kuza Indian Hemp Hair & Scalp Treatment, 8 Oz      1
# 2             Dry  Softee Indian Hemp Hair & Scalp Treatment 3 oz...      1
# 3             Dry  Mega Growth Profectiv Moisturizing Repairing L...      1
# 4           Curly  Feel It Formula- Strengthening Balm 4oz., All ...      1
# 5  All Hair Types  Jamaican Mango & Lime Nourishing Island Oil Ha...      1
# 6         Damaged  Softee Hair & Scalp Treatment, Indian Hemp, 5 ...      1
# 7             Dry  Softee Light And Natural Indian Hemp Hair And ...      1
# 8             Dry  FANTASIA Avocado & Cilantro Leave-in Treatment...      1
#
#   Hair Care Key Benefits Condition Ingredient Preference         Weight
# 0           Moisturizing       New          Paraben-Free
# 1              Repairing       New                              9.84 lb
# 2           Conditioning       New                             0.24 lbs
# 3           Moisturizing       New                        1.1325 POUNDS
# 4             Nourishing       New          Paraben-Free        5.47 oz
# 5             Nourishing       New          Paraben-Free        0.5 lbs
# 6             Scalp Care       New                                 1 lb
# 7                              New                                 1 lb
# 8             Nourishing       New          Paraben-Free        0.88 lb

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define dataset URL
url = 'https://raw.githubusercontent.com/CodeYouOrg/DataOpenClass/main/SalaryData.csv'

# Read CSV into DataFrame
df = pd.read_csv(url)

# Drop unnecessary columns
columns_to_drop = ['Overtime_Rate', 'Incentive_Allowance', 'Other', 'ObjectId']
df = df.drop(columns=columns_to_drop)

# Drop rows with missing values
df = df.dropna()

# Filter data: employees who made $100K+ in 2022
df = df[(df['CalYear'] == 2022) & (df['YTD_Total'] >= 100000)]

# Sorting the top 10 earners
top_10_earners = df.sort_values(by='YTD_Total', ascending=False).head(10)

# Plot top 10 earners
plt.bar(top_10_earners['Employee_Name'], top_10_earners['YTD_Total'])
plt.xlabel('Employee Name')
plt.ylabel('Total Salary ($)')
plt.title('Top 10 Salaries in 2022')
plt.xticks(rotation=45) 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/CodeYouOrg/DataOpenClass/refs/heads/main/SalaryData.csv'
df = pd.read_csv(url)

# dropping columns we dont need
columns_to_drop = ['Overtime_Rate',	'Incentive_Allowance', 'Other', 'ObjectId']
df = df.drop(columns=columns_to_drop)

# We dont have a ton of missing data so we are dropping the NaNs 
df = df.dropna()

df = df[(df['CalYear'] == 2022) & (df['YTD_Total'] >= 100000)]

# Sort and select the top 10 earners
top_earners = df.sort_values(by='YTD_Total', ascending=False).head(10)

# Create the bar graph
plt.bar(top_earners['Employee_Name'], top_earners['YTD_Total'])

# Add title
plt.title('Top 10 Salaries in 2022')

# Show the plot
plt.show()

# %%
import pandas as pd

# Sample Data
data = {
    'EmployeeID': [101, 102, 103, 104, 105],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Department': ['HR', 'Engineering', 'Engineering', 'HR', 'Finance'],
    'JobTitle': ['Manager', 'Engineer', 'Engineer', 'Clerk', 'Analyst'],
    'Salary': [75000, 95000, 80000, 50000, 60000],
    'HoursWorked': [40, 45, 40, 38, 42],
    'Bonus': [5000, 7000, 3000, 2000, 4000]
}

# Create a DataFrame
df = pd.DataFrame(data)


# -----------------------------------------------------
# convert this to a function location_report() 
# to take in a dataframe as an argument 
# and return the report
# -----------------------------------------------------

def location_report(df):
    # Grouping by department and calculating the sum of Salary and HoursWorked
    grouped_by_dept = df.groupby('Department').agg({
        'Salary': 'sum',
        'HoursWorked': 'sum'
    }).reset_index()

# Grouping by department and calculating the sum of Salary and HoursWorked
grouped_by_dept = df.groupby('Department').agg({
    'Salary': 'sum',
    'HoursWorked': 'sum'
}).reset_index()

# Aggregating Salary and HoursWorked for sum, mean, and max values
agg_data = df.groupby('Department').agg({
    'Salary': ['sum', 'mean', 'max'],
    'HoursWorked': ['sum', 'mean']
}).reset_index()

# Creating TotalSalary column
df['TotalSalary'] = df['Salary'] + df['Bonus']

# Calculating the total salary and the SalaryPercentage for each row
total_salary = df['TotalSalary'].sum()
df['SalaryPercentage'] = df['TotalSalary'] / total_salary * 100

# Generating the report
print("=== Department Summary Report ===")
print("\nGrouped by Department (Salary and Hours Worked):")
print(grouped_by_dept)

print("\nAggregated Data (Salary - Sum, Mean, Max; Hours Worked - Sum, Mean):")
print(agg_data)

print("\nDetailed Data with Total Salary and Salary Percentage:")
print(df[['Department', 'TotalSalary', 'SalaryPercentage']])

# Printing out some summary information
print("\nTotal Salary Across All Departments: ${:,.2f}".format(total_salary),'\n')

# Check if any employee's TotalSalary is greater than or equal to 85000
high_salary_employees = df[df['TotalSalary'] >= 85000]

if not high_salary_employees.empty:
    print('We recommend cutting the following employees:')
    for name in high_salary_employees['Name']:
        print(name)
else:
    print('No cuts needed at this location')
    

# runs your function on the above df
location_report(df)
# Out:
# === Department Summary Report ===
#
# Grouped by Department (Salary and Hours Worked):
#     Department  Salary  HoursWorked
# 0  Engineering  175000           85
# 1      Finance   60000           42
# 2           HR  125000           78
#
# Aggregated Data (Salary - Sum, Mean, Max; Hours Worked - Sum, Mean):
#     Department  Salary                 HoursWorked
#                    sum     mean    max         sum  mean
# 0  Engineering  175000  87500.0  95000          85  42.5
# 1      Finance   60000  60000.0  60000          42  42.0
# 2           HR  125000  62500.0  75000          78  39.0
#
# Detailed Data with Total Salary and Salary Percentage:
#     Department  TotalSalary  SalaryPercentage
# 0           HR        80000         20.997375
# 1  Engineering       102000         26.771654
# 2  Engineering        83000         21.784777
# 3           HR        52000         13.648294
# 4      Finance        64000         16.797900
#
# Total Salary Across All Departments: $381,000.00
#
# We recommend cutting the following employees:
# Bob
#     Department  Salary                 HoursWorked
#                    sum     mean    max         sum  mean
# 0  Engineering  175000  87500.0  95000          85  42.5
# 1      Finance   60000  60000.0  60000          42  42.0
# 2           HR  125000  62500.0  75000          78  39.0
#
# Detailed Data with Total Salary and Salary Percentage:
#     Department  TotalSalary  SalaryPercentage
# 0           HR        80000         20.997375
# 1  Engineering       102000         26.771654
# 2  Engineering        83000         21.784777
# 3           HR        52000         13.648294
# 4      Finance        64000         16.797900
#
# Total Salary Across All Departments: $381,000.00
#
# We recommend cutting the following employees:
# Bob

# %%
import pandas as pd

data = {
    'EmployeeID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Hannah', 'Ivy', 'Jack', 'Kim', 'Liam', 'Megan', 'Nathan', 'Olivia'],
    'Department': ['HR', 'Engineering', 'Engineering', 'HR', 'Finance', 'Sales', 'Sales', 'Engineering', 'HR', 'Finance', 'Sales', 'HR', 'Engineering', 'Sales', 'HR'],
    'JobTitle': ['Manager', 'Engineer', 'Engineer', 'Clerk', 'Analyst', 'Sales Rep', 'Sales Rep', 'Engineer', 'Clerk', 'Analyst', 'Sales Rep', 'Manager', 'Engineer', 'Sales Rep', 'Clerk'],
    'Salary': [75000, 95000, 80000, 50000, 60000, 70000, 72000, 85000, 52000, 62000, 75000, 77000, 80000, 73000, 54000],
    'HoursWorked': [40, 45, 40, 38, 42, 40, 38, 45, 39, 41, 42, 40, 44, 39, 38],
    'Bonus': [5000, 7000, 3000, 2000, 4000, 5000, 4000, 6000, 2500, 3000, 5500, 4500, 6000, 5000, 2500]
}

# Create DataFrame
london = pd.DataFrame(data)


def location_report(df):
  # Grouping by department and calculating the sum of Salary and HoursWorked
  grouped_by_dept = df.groupby('Department').agg({
      'Salary': 'sum',
      'HoursWorked': 'sum'
  }).reset_index()

  # Aggregating Salary and HoursWorked for sum, mean, and max values
  agg_data = df.groupby('Department').agg({
      'Salary': ['sum', 'mean', 'max'],
      'HoursWorked': ['sum', 'mean']
  }).reset_index()

  # Creating TotalSalary column
  df['TotalSalary'] = df['Salary'] + df['Bonus']

  # Calculating the total salary and the SalaryPercentage for each row
  total_salary = df['TotalSalary'].sum()
  df['SalaryPercentage'] = df['TotalSalary'] / total_salary * 100

  # Generating the report
  print("=== Department Summary Report ===")
  print("\nGrouped by Department (Salary and Hours Worked):")
  print(grouped_by_dept)

  print("\nAggregated Data (Salary - Sum, Mean, Max; Hours Worked - Sum, Mean):")
  print(agg_data)

  print("\nDetailed Data with Total Salary and Salary Percentage:")
  print(df[['Department', 'TotalSalary', 'SalaryPercentage']])

  # Printing out some summary information
  print("\nTotal Salary Across All Departments: ${:,.2f}".format(total_salary),'\n')

  # Check if any employee's TotalSalary is greater than or equal to 85000
  high_salary_employees = df[df['TotalSalary'] >= 85000]

  if not high_salary_employees.empty:
      print('We recommend cutting the following employees:')
      for name in high_salary_employees['Name']:
          print(name)
  else:
      print('No cuts needed at this location')

  return 

# test the function with londons data 

location_report(london)
# Out:
# === Department Summary Report ===
#
# Grouped by Department (Salary and Hours Worked):
#     Department  Salary  HoursWorked
# 0  Engineering  340000          174
# 1      Finance  122000           83
# 2           HR  308000          195
# 3        Sales  290000          159
#
# Aggregated Data (Salary - Sum, Mean, Max; Hours Worked - Sum, Mean):
#     Department  Salary                 HoursWorked
#                    sum     mean    max         sum   mean
# 0  Engineering  340000  85000.0  95000         174  43.50
# 1      Finance  122000  61000.0  62000          83  41.50
# 2           HR  308000  61600.0  77000         195  39.00
# 3        Sales  290000  72500.0  75000         159  39.75
#
# Detailed Data with Total Salary and Salary Percentage:
#      Department  TotalSalary  SalaryPercentage
# 0            HR        80000          7.111111
# 1   Engineering       102000          9.066667
# 2   Engineering        83000          7.377778
# 3            HR        52000          4.622222
# 4       Finance        64000          5.688889
# 5         Sales        75000          6.666667
# 6         Sales        76000          6.755556
# 7   Engineering        91000          8.088889
# 8            HR        54500          4.844444
# 9       Finance        65000          5.777778
# 10        Sales        80500          7.155556
# 11           HR        81500          7.244444
# 12  Engineering        86000          7.644444
# 13        Sales        78000          6.933333
# 14           HR        56500          5.022222
#
# Total Salary Across All Departments: $1,125,000.00
#
# We recommend cutting the following employees:
# Bob
# Hannah
# Megan
